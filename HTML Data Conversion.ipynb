# %%
import pandas as pd

# %%
data = pd.read_csv("cities.csv")
data
# Out:
#      Unnamed: 0          City  Max Temp  Cloudiness  Humidity  Wind Speed  \
# 0             0  Punta Arenas     46.40          75        66       21.85
# 1             1      Kamaishi     33.51         100        83        4.32
# 2             2      Chumikan    -13.14         100        88        8.72
# 3             3   Henties Bay     68.00           6        85        6.13
# 4             4   Pangnirtung     -4.00           1        77        4.61
# ..          ...           ...       ...         ...       ...         ...
# 558         558       Kassala     70.88          61        58        5.95
# 559         559       Jiangdu     42.01          18        94       14.85
# 560         560        Lompoc     53.60          90        87       14.97
# 561         561       Honāvar     70.32           2        71        3.56
# 562         562       Husavik     15.80          90        86        9.31
#
#     Country  Latitude  Longitude        Date
# ...

# %%
data_html = data.to_html()
data_html
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>Unnamed: 0</th>\n      <th>City</th>\n      <th>Max Temp</th>\n      <th>Cloudiness</th>\n      <th>Humidity</th>\n      <th>Wind Speed</th>\n      <th>Country</th>\n      <th>Latitude</th>\n      <th>Longitude</th>\n      <th>Date</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>0</td>\n      <td>Punta Arenas</td>\n      <td>46.40</td>\n      <td>75</td>\n      <td>66</td>\n      <td>21.85</td>\n      <td>CL</td>\n      <td>-53.1500</td>\n      <td>-70.9167</td>\n      <td>1611788886</td>\n    </tr>\n    <tr>\n      <th>1</th>\n      <td>1</td>\n      <td>Kamaishi</td>\n      <td>33.51</td>\n      <td>100</td>\n      <td>83</td>\n      <td>4.32</td>\n      <td>JP</td>\n      <td>39.2667</td>\n      <td>141.8833</td>\n      <td>1611788887</td>\n    </tr>\n    <tr>\n      <th>2</th>\n      <td>2</td>\n      <td>Chumikan</td>\n      <td>-13.14</
# ...

# %%
data.to_html('table.html')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-c8b3444c401e> in <module>
#       1 data.to_html('table.html')
# ----> 2 table.html
#
# NameError: name 'table' is not defined
